# %%
import numpy as np
import matplotlib.pyplot as plt
X_data = np.random.random(1000) * 100
Y_data = np.random.random(1000) * 100
plt.scatter(X_data,Y_data, c="red", marker="*", alpha=0.4)

# %%
years = [2006 + x for x in range(10)]
weights = [80, 83, 84, 83, 81, 79, 80, 83, 85, 82]
plt.plot(years, weights, "r--")

# %%
x = ["c++", "c#", "python", "java", "go"]
y = [40, 30,150,40,1]
plt.bar(x,y, color="r", width=0.1)
# Out:
# <BarContainer object of 5 artists>

# %%
ages = np.random.normal(20,1.5 ,1000)
plt.hist(ages, bins=100)
# Out:
# (array([ 1.,  0.,  0.,  1.,  0.,  0.,  2.,  0.,  0.,  1.,  1.,  0.,  2.,
#          0.,  3.,  2.,  1.,  3.,  5.,  4.,  3.,  8.,  1.,  7.,  2.,  3.,
#         11.,  7.,  4.,  6., 10.,  5., 10., 11.,  9., 16.,  7., 18., 18.,
#         13., 16., 19., 18., 17., 22., 25., 26., 26., 27., 17., 23., 31.,
#         20., 21., 26., 24., 26., 24., 14., 17., 12., 14., 14., 30., 22.,
#         18., 15., 14., 18., 19., 17., 15., 16.,  7., 13., 11.,  5., 13.,
#         10., 14.,  9.,  6., 10.,  4.,  4.,  2.,  8.,  6.,  1.,  4.,  0.,
#          2.,  4.,  1.,  2.,  0.,  2.,  0.,  1.,  3.]),
#  array([15.4424855 , 15.52659441, 15.61070331, 15.69481221, 15.77892112,
#         15.86303002, 15.94713893, 16.03124783, 16.11535674, 16.19946564,
#         16.28357455, 16.36768345, 16.45179235, 16.53590126, 16.62001016,
#         16.70411907, 16.78822797, 16.87233688, 16.95644578, 17.04055469,
#         17.12466359, 17.20877249, 17.2928814 , 17.3769903 , 17.46109921,
#         17.54520811, 17.62931702, 17.71342592, 17.79753483, 17.88164373,
#         17.96575264, 18.04986154, 18.13397044, 18.21807935, 18.30218825,
#         18.38629716, 18.47040606, 18.55451497, 18.63862387, 18.72273278,
#         18.80684168, 18.89095058, 18.97505949, 19.05916839, 19.1432773 ,
#         19.2273862 , 19.31149511, 19.39560401, 19.47971292, 19.56382182,
#         19.64793072, 19.73203963, 19.81614853, 19.90025744, 19.98436634,
#         20.06847525, 20.15258415, 20.23669306, 20.32080196, 20.40491087,
#         20.48901977, 20.57312867, 20.65723758, 20.74134648, 20.82545539,
#         20.90956429, 20.9936732 , 21.0777821 , 21.16189101, 21.24599991,
#         21.33010881, 21.41421772, 21.49832662, 21.58243553, 21.66654443,
#         21.75065334, 21.83476224, 21.91887115, 22.00298005, 22.08708895,
#         22.17119786, 22.25530676, 22.33941567, 22.42352457, 22.50763348,
#         22.59174238, 22.67585129, 22.75996019, 22.84406909, 22.928178  ,
#         23.0122869 , 23.09639581, 23.18050471, 23.26461362, 23.34872252,
#         23.43283143, 23.51694033, 23.60104924, 23.68515814, 23.76926704,
#         23.85337595]),
#  <BarContainer object of 100 artists>)
